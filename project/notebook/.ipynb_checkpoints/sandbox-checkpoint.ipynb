# %% [markdown]
# ### Dependencies
# ____

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from statsmodels.tsa.seasonal import seasonal_decompose
from pylab import rcParams

# %matplotlib inline

# %% [markdown]
# ### Load Dataset
# ____

# %%
dataset = "../resources/household_power_consumption.csv"
df = pd.read_csv(dataset, parse_dates=True, sep=";", low_memory=False)

df.head()
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# 3           23.000          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0

# %% [markdown]
# #### Merge Date and Time columns into a timestamp field
# _____

# %%
df['timestamp'] = pd.to_datetime(df['Date'] + ' ' + df['Time'])
df.set_index('timestamp', inplace=True)
#df.index.freq = 'T'

###### split into different phases
#df['power'] = pd.to_numeric(df['Global_active_power'], errors='coerce')

#drop_col = ['Date', 'Time', 'Global_active_power', 'Global_reactive_power', 'Voltage', 'Global_intensity', 'Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3']
#df.drop(drop_col, axis=1, inplace=True)

#df.dropna(axis=0, inplace=True)
#df['power'] = df['power'].astype(float)

#df.info()
# Out:
#                            Date      Time Global_active_power  \
# timestamp
# 2006-12-16 17:24:00  16/12/2006  17:24:00               4.216
# 2006-12-16 17:25:00  16/12/2006  17:25:00               5.360
# 2006-12-16 17:26:00  16/12/2006  17:26:00               5.374
# 2006-12-16 17:27:00  16/12/2006  17:27:00               5.388
# 2006-12-16 17:28:00  16/12/2006  17:28:00               3.666
# ...                         ...       ...                 ...
# 2010-11-26 20:58:00  26/11/2010  20:58:00               0.946
# 2010-11-26 20:59:00  26/11/2010  20:59:00               0.944
# 2010-11-26 21:00:00  26/11/2010  21:00:00               0.938
# 2010-11-26 21:01:00  26/11/2010  21:01:00               0.934
# 2010-11-26 21:02:00  26/11/2010  21:02:00               0.932
#
#                     Global_reactive_power  Voltage Global_intensity  \
# timestamp
# 2006-12-16 17:24:00                 0.418  234.840           18.400
# ...

# %%
df['timestamp'] = pd.to_datetime(df['Date'] + ' ' + df['Time'])

# %%
df['timestamp'].asfreq(freq='AS')
# Out:
# 1970-01-01   NaT
# Freq: AS-JAN, Name: timestamp, dtype: datetime64[ns]

# %%
df.dropna(axis=0, inplace=True)

# %%
#df.set_index('timestamp', inplace=True)
#df.index.freq = 'T'
#df.index.inferred_freq

# %% [markdown]
# #### Plot Dataset
# ____

# %%
df.plot(figsize=(12,6));

# %% [markdown]
# #### Decompose Time Series Data
# ____

# %% [markdown]
# df.asfreq(df.index.freq or to_offset(timeframe.Timespan).freqstr)
# #result = seasonal_decompose(df['power'],model='multiplicative')

# %%
df.asfreq(df.index.freq or to_offset(timeframe.Timespan).freqstr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-931cf75f5393> in <module>
# ----> 1 df.asfreq(df.index.freq or to_offset(timeframe.Timespan).freqstr)
#
# NameError: name 'to_offset' is not defined

# %%
np.array(['2020-01-03', '2020-03-16', '2020-03-17'], dtype='datetime64')
# Out:
# array(['2020-01-03', '2020-03-16', '2020-03-17'], dtype='datetime64[D]')

# %%
np.array(['2020-01-03 03:00:00', '2020-03-16 03:30:00', '2020-03-17 04:00:00'], dtype='datetime64')
# Out:
# array(['2020-01-03T03:00:00', '2020-03-16T03:30:00',
#        '2020-03-17T04:00:00'], dtype='datetime64[s]')

# %%
np.array(['2018', '2019', '2020'], dtype='datetime64')
# Out:
# array(['2018', '2019', '2020'], dtype='datetime64[Y]')

# %%
# https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#timeseries-offset-aliases
pd.date_range('2020-02-01 03:00', periods=7, freq='B')
# Out:
# DatetimeIndex(['2020-02-03', '2020-02-04', '2020-02-05', '2020-02-06',
#                '2020-02-07', '2020-02-10', '2020-02-11'],
#               dtype='datetime64[ns]', freq='B')
