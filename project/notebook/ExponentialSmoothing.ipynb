# %% [markdown]
# #### Dependencies
# _____

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.tsa.seasonal import seasonal_decompose
from pylab import rcParams

# %matplotlib inline

# %% [markdown]
# #### Read Dataset
# _____

# %%
dataset = '../resources/daily_household_power_consumption.csv'

master = pd.read_csv(dataset, 
                     sep=",", 
                     low_memory=False, 
                     header=0, 
                     infer_datetime_format=True,
                     parse_dates=['datetime'], 
                     index_col=['datetime']
                     )

master = master.asfreq('D')
master.head(10)
# Out:
#             Global_active_power  Global_reactive_power    Voltage  \
# datetime
# 2006-12-16             1209.176                 34.922   93552.53
# 2006-12-17             3390.460                226.006  345725.32
# 2006-12-18             2203.826                161.792  347373.64
# 2006-12-19             1666.194                150.942  348479.01
# 2006-12-20             2225.748                160.998  348923.61
# 2006-12-21             1723.288                144.434  347096.41
# 2006-12-22             2341.338                186.906  347305.75
# 2006-12-23             4773.386                221.470  345795.95
# 2006-12-24             2550.012                149.900  348029.91
# 2006-12-25             2743.120                240.280  350495.90
#
#             Global_intensity  kitchen_active_energy  laundry_active_energy  \
# datetime
# 2006-12-16            5180.8                    0.0                  546.0
# ...

# %% [markdown]
# #### Decompose Timeseries components
# ______

# %%
#result = seasonal_decompose(x=master['Global_active_power'], model='multiplicative',freq=1)
#result = seasonal_decompose(x=master['Global_active_power'], model='additive')
#result = seasonal_decompose(x=master['Global_active_power'], model='multiplicative')
#result = seasonal_decompose(x=master['sub_metering_4'], model='additive')

result = seasonal_decompose(x=master['Global_active_power'], model='additive')

rcParams['figure.figsize'] = 14,5

result.plot();

# %%
result = seasonal_decompose(x=master['Global_active_power'], model='multiplicative')
result.plot();
