# %% [markdown]
# #### Dependencies
# ____

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score

from tensorflow.keras.utils  import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

from mlxtend.plotting import plot_confusion_matrix

# %matplotlib inline

sns.set_style("whitegrid")

# %% [markdown]
# #### Load Data
# _____

# %% [markdown]
# ##### **Features Description**
#  + **Continuous**
#      + age
#      + trestbps (resting blood pressure (in mm Hg on admission to the hospital))
#      + chol (serum cholestoral in mg/dl)
#      + thalach (pncaden (sum of 5, 6, and 7))
#
#
#  + **Categorical**
#     + sex
#         + 1 = male
#         + 0 = female
#      + cp (chest pain type)
#          + 1 = typical angina
#          + 2 = atypical angina
#          + 3 = non-anginal pain
#          + 4 = asymptomatic
#
#      + fbs (fasting blood sugar > 120 mg/dl)
#          + 1 = true
#          + 0 = false
#
#      + restecg (resting electrocardiographic results)
#          + 0 = normal
#          + 1 = having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
#          + 2 = showing probable or definite left ventricular hypertrophy by Estes' criteria
#
#      + exang (exercise induced angina)
#          + 1 = yes
#          + 0 = no
#      + oldpeak (ST depression induced by exercise relative to rest)
#      + slope (the slope of the peak exercise ST segment)
#          + 1 = upsloping
#          + 2 = flat
#          + 3 = downsloping
#      + ca (number of major vessels (0-3) colored by flourosopy)
#         + 0 = zero fluroscopy colored Major Vessels
#         + 1 = one fluroscopy colored Major Vessels
#         + 2 = two fluroscopy colored Major Vessels
#         + 3 = three fluroscopy colored Major Vessels
#
#      + thal
#          + 3 = normal
#          + 6 = fixed defect
#          + 7 = reversable defect
#
# ##### **Label**
# + 0 = Healthy
# + 1-4 = Sick

# %%
columns = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'label']
master = pd.read_csv('../../resources/processed.cleveland.data', names=columns)

master.head(5)
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  label
# 0    3.0  0.0  6.0      0
# 1    2.0  3.0  3.0      2
# 2    2.0  2.0  7.0      1
# 3    3.0  0.0  3.0      0
# 4    1.0  0.0  3.0      0

# %%
master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    float64
#  1   sex       303 non-null    float64
#  2   cp        303 non-null    float64
#  3   trestbps  303 non-null    float64
#  4   chol      303 non-null    float64
#  5   fbs       303 non-null    float64
#  6   restecg   303 non-null    float64
#  7   thalach   303 non-null    float64
#  8   exang     303 non-null    float64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    float64
#  11  ca        303 non-null    object
#  12  thal      303 non-null    object
#  13  label     303 non-null    int64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 33.3+ KB

# %% [markdown]
# #### Data Cleanup
# _____

# %% [markdown]
# ##### Features columns ca and thal contains non-numerical data

# %%
master['ca'].value_counts()
# Out:
# 0.0    176
# 1.0     65
# 2.0     38
# 3.0     20
# ?        4
# Name: ca, dtype: int64

# %%
master['thal'].value_counts()
# Out:
# 3.0    166
# 7.0    117
# 6.0     18
# ?        2
# Name: thal, dtype: int64

# %% [markdown]
# ##### Replacing the missing values by most frequent value

# %%
cond = master['ca'] == '?'
for row in master[cond]['ca'].index:
    master.iloc[row, 11] = master['ca'].mode().values
    
cond = master['thal'] == '?'
for row in master[cond]['thal'].index:
    master.iloc[row, 12] = master['thal'].mode().values
    
master['ca'] = master['ca'].astype('float64')
master['thal'] = master['thal'].astype('float64')

master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    float64
#  1   sex       303 non-null    float64
#  2   cp        303 non-null    float64
#  3   trestbps  303 non-null    float64
#  4   chol      303 non-null    float64
#  5   fbs       303 non-null    float64
#  6   restecg   303 non-null    float64
#  7   thalach   303 non-null    float64
#  8   exang     303 non-null    float64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    float64
#  11  ca        303 non-null    float64
#  12  thal      303 non-null    float64
#  13  label     303 non-null    int64
# dtypes: float64(13), int64(1)
# memory usage: 33.3 KB

# %% [markdown]
# ##### Converting label to binary (0 =  Healthy, 1 = Sick)

# %%
master['label'] = master['label'].apply(lambda x: 0 if x == 0 else 1)

# %% [markdown]
# ##### Checking for any missing data
# ___

# %%
master.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# label       0
# dtype: int64

# %% [markdown]
# #### Data Analysis
# _____

# %% [markdown]
# ##### Categorical Labels
# ___

# %%
def label_cp(x):
    if (x == 1):
        return 'typical-angina'
    
    elif (x == 2):
        return 'atypical-angina'
    
    elif (x == 3):
        return 'non-anginal-pain'
    
    else:
        return 'asymptomatic'
    
def label_restecg(x):
    if (x == 0):
        return 'normal'
    elif (x == 1):
        return 'wave-abnormality'
    else:
        return 'ventricular-hypertrophy'
    
def label_slope(x):
    if (x == 1):
        return 'upsloping'
    
    elif (x == 2):
        return 'flat'
    
    else:
        return 'downsloping'
    
def label_thal(x):
    if (x == 3):
        return 'normal'
    
    elif (x == 6):
        return 'fixed-defect'
    
    else:
        return 'reversable-defect'
    
def label_ca(x):
    if (x == 0):
        return 'zero'
    
    elif(x == 1):
        return 'one'
    
    elif(x == 2):
        return 'two'
    
    else:
        return 'three'        
        
master['sex'] = master['sex'].apply(lambda x: 'Male' if x == 1 else 'Female')
master['cp'] = master['cp'].apply(label_cp)
master['fbs'] = master['fbs'].apply(lambda x: 'False' if x == 0 else 'True')
master['restecg'] = master['restecg'].apply(label_restecg)
master['exang'] = master['exang'].apply(lambda x: 'No' if x == 0 else 'Yes')
master['slope'] = master['slope'].apply(label_slope)
master['thal'] = master['thal'].apply(label_thal)
master['ca'] = master['ca'].apply(label_ca)

data_d = master.copy(deep=True)
data_d['label'] = data_d['label'].apply(lambda x: 'Healthy' if x == 0 else 'Sick')

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='label', data=data_d);
plt.tight_layout()

# %% [markdown]
# ###### **Dataset balance between sick and healthy seems to be good (no so much difference).**

# %% [markdown]
# ##### Distribution of data accross features
# ___

# %%
fig, axes =  plt.subplots(nrows=1, ncols=2, figsize=(14,4), dpi=100)

axes[0].set_title('Gender Distribution')
sns.countplot(x=data_d['sex'],ax=axes[0])

axes[1].set_title('Chest Pain Type')
sns.countplot(x=data_d['cp'], ax=axes[1])

fig, ax =  plt.subplots(nrows=1, ncols=2, figsize=(14,4), dpi=100)

ax[0].set_title('Age Distribution')
sns.distplot(data_d['age'], kde=False,color='blue', ax=ax[0])

ax[1].set_title('Blood Pressure Distribution')
sns.distplot(data_d['trestbps'], kde=False,color='red', ax=ax[1])


plt.tight_layout()

# %% [markdown]
# ##### Distribution of data accross features versus label
# ____

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20,10))

sns.boxplot(x='label', y='age', data=data_d, ax=axes[0][0], hue='sex')
axes[0][0].set_title('Distribution of Heart Disease accross Gender')

axes[0][1].set_title('Distribution of Heart Disease accross Blood Pressure')
sns.boxplot(x='label', y='trestbps', data=data_d, hue='sex', ax=axes[0][1])

axes[1][0].set_title('Distribution of Heart Disease accross Chest Pain')
sns.boxplot(x='label', y='age', data=data_d, hue='cp', ax=axes[1][0])

axes[1][1].set_title('Distribution of Heart Disease accross Induced Angina')
sns.boxplot(x='label', y='age', data=data_d, hue='exang', ax=axes[1][1])


plt.tight_layout()

# %% [markdown]
# ##### Correlation accross continuous features
# ___

# %%
plt.figure(figsize=(14,6))

sns.heatmap(master[['age', 'trestbps', 'chol', 'thalach']].corr(), annot=True, cmap='viridis');
plt.tight_layout()

# %% [markdown]
# ##### Correlation between age and blood pressure and between age and cholestoral
# ___

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14,6))

axes[0].set_title('Correlation between age and blood pressure')
sns.regplot(x='age', y='trestbps',data=master, ax=axes[0], color='red')

axes[1].set_title('Correlation between age and cholestoral')
sns.regplot(x='age', y='chol',data=master, ax=axes[1], color='green')

plt.tight_layout()

# %% [markdown]
# #### Encode Categorial Data
# _____

# %%
columns = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal']
for item in columns:
    print (item)
    print(master[item].value_counts())
    print ('\n')
# Out:
# sex
# Male      206
# Female     97
# Name: sex, dtype: int64
#
#
# cp
# asymptomatic        144
# non-anginal-pain     86
# atypical-angina      50
# typical-angina       23
# Name: cp, dtype: int64
#
#
# fbs
# False    258
# True      45
# Name: fbs, dtype: int64
#
#
# restecg
# normal                     151
# ventricular-hypertrophy    148
# wave-abnormality             4
# Name: restecg, dtype: int64
#
#
# exang
# No     204
# Yes     99
# Name: exang, dtype: int64
#
#
# slope
# upsloping      142
# flat           140
# downsloping     21
# Name: slope, dtype: int64
#
#
# ca
# zero     180
# one       65
# two       38
# three     20
# Name: ca, dtype: int64
#
#
# thal
# normal               168
# reversable-defect    117
# fixed-defect          18
# Name: thal, dtype: int64

# %% [markdown]
# #### Dummy variables
# _____

# %%
columns = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal']
dummies = pd.get_dummies(master[columns], drop_first=True)

master = master.drop(columns, axis=1)
master = pd.concat([master, dummies], axis=1)

master.columns
# Out:
# Index(['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'label', 'sex_Male',
#        'cp_atypical-angina', 'cp_non-anginal-pain', 'cp_typical-angina',
#        'fbs_True', 'restecg_ventricular-hypertrophy',
#        'restecg_wave-abnormality', 'exang_Yes', 'slope_flat',
#        'slope_upsloping', 'ca_three', 'ca_two', 'ca_zero', 'thal_normal',
#        'thal_reversable-defect'],
#       dtype='object')

# %%
master.shape
# Out:
# (303, 21)

# %% [markdown]
# #### Method 1
# ##### Split Train and Test Data Method
# _____

# %% [markdown]
# #### Split Train and Test Data
# ________

# %%
X = master.drop('label', axis=1).values    # NumPy array (TF requirement)
y = master['label'].values                 # NumPy array (TF requirement)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
print(f'X_train shape : {X_train.shape} - Y_train shape : {y_train.shape}')
print(f'X_test shape : {X_test.shape} - Y_test shape : {y_test.shape}')
# Out:
# X_train shape : (212, 20) - Y_train shape : (212,)
# X_test shape : (91, 20) - Y_test shape : (91,)

# %% [markdown]
# #### Scale & Normalize Training Features
# ____

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### Create Model
# ____

# %%
model = Sequential()

model.add(Dense(units=20, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=15, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(units=1, activation='sigmoid'))    

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
early_stop = EarlyStopping(monitor='loss', mode='min', verbose=0, patience=25)

# %%
history = model.fit(x=X_train, y=y_train, epochs=600, batch_size=10, verbose=1, callbacks=[early_stop])
# Out:
# Train on 212 samples
# Epoch 1/600
# 212/212 [==============================] - 2s 8ms/sample - loss: 0.7376 - accuracy: 0.5094
# Epoch 2/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.6777 - accuracy: 0.5519
# Epoch 3/600
# 212/212 [==============================] - 0s 108us/sample - loss: 0.6344 - accuracy: 0.6321
# Epoch 4/600
# 212/212 [==============================] - 0s 118us/sample - loss: 0.6542 - accuracy: 0.5991
# Epoch 5/600
# 212/212 [==============================] - 0s 108us/sample - loss: 0.6251 - accuracy: 0.6274
# Epoch 6/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.6063 - accuracy: 0.6604
# Epoch 7/600
# 212/212 [==============================] - 0s 113us/sample - loss: 0.6425 - accuracy: 0.6557
# Epoch 8/600
# 212/212 [==============================] - 0s 127us/sample - loss: 0.6016 - accuracy: 0.6792
# Epoch 9/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.5599 - accuracy: 0.7170
# Epoch 10/600
# 212/212 [==============================] - 0s 127us/sample - loss: 0.5674 - accuracy: 0.6792
# Epoch 11/600
# 212/212 [==============================] - 0s 127us/sample - loss: 0.5393 - accuracy: 0.7358
# Epoch 12/600
# 212/212 [==============================] - 0s 118us/sample - loss: 0.6035 - accuracy: 0.6698
# Epoch 13/600
# 212/212 [==============================] - 0s 127us/sample - loss: 0.5554 - accuracy: 0.6934
# Epoch 14/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.5370 - accuracy: 0.7500
# Epoch 15/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.5120 - accuracy: 0.7594
# Epoch 16/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.4953 - accuracy: 0.7594
# Epoch 17/600
# 212/212 [==============================] - 0s 137us/sample - loss: 0.5106 - accuracy: 0.7500
# Epoch 18/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.4923 - accuracy: 0.7642
# Epoch 19/600
# 212/212 [==============================] - 0s 104us/sample - loss: 0.4807 - accuracy: 0.7925
# Epoch 20/600
# 212/212 [==============================] - 0s 127us/sample - loss: 0.4727 - accuracy: 0.7925
# Epoch 21/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.4892 - accuracy: 0.7925
# Epoch 22/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.5044 - accuracy: 0.7594
# Epoch 23/600
# 212/212 [==============================] - 0s 127us/sample - loss: 0.4621 - accuracy: 0.7830
# Epoch 24/600
# 212/212 [==============================] - 0s 127us/sample - loss: 0.5000 - accuracy: 0.7689
# Epoch 25/600
# 212/212 [==============================] - 0s 118us/sample - loss: 0.4534 - accuracy: 0.8066
# Epoch 26/600
# 212/212 [==============================] - 0s 118us/sample - loss: 0.4132 - accuracy: 0.8632
# Epoch 27/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.4521 - accuracy: 0.8066
# Epoch 28/600
# 212/212 [==============================] - 0s 113us/sample - loss: 0.4625 - accuracy: 0.7972
# Epoch 29/600
# 212/212 [==============================] - 0s 118us/sample - loss: 0.4014 - accuracy: 0.8396
# Epoch 30/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.4514 - accuracy: 0.7925
# Epoch 31/600
# 212/212 [==============================] - 0s 127us/sample - loss: 0.4012 - accuracy: 0.8632
# Epoch 32/600
# 212/212 [==============================] - 0s 127us/sample - loss: 0.3765 - accuracy: 0.8443
# Epoch 33/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.4228 - accuracy: 0.8302
# Epoch 34/600
# 212/212 [==============================] - 0s 137us/sample - loss: 0.3814 - accuracy: 0.8396
# Epoch 35/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.3872 - accuracy: 0.8585
# Epoch 36/600
# 212/212 [==============================] - 0s 127us/sample - loss: 0.3664 - accuracy: 0.8443
# Epoch 37/600
# 212/212 [==============================] - 0s 127us/sample - loss: 0.3958 - accuracy: 0.8443
# Epoch 38/600
# 212/212 [==============================] - 0s 137us/sample - loss: 0.4223 - accuracy: 0.8585
# Epoch 39/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.4128 - accuracy: 0.8208
# Epoch 40/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.3734 - accuracy: 0.8396
# Epoch 41/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.3891 - accuracy: 0.8585
# Epoch 42/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.3684 - accuracy: 0.8443
# Epoch 43/600
# 212/212 [==============================] - 0s 127us/sample - loss: 0.4068 - accuracy: 0.8396
# Epoch 44/600
# 212/212 [==============================] - 0s 141us/sample - loss: 0.3533 - accuracy: 0.8538
# Epoch 45/600
# 212/212 [==============================] - 0s 141us/sample - loss: 0.3761 - accuracy: 0.8491
# Epoch 46/600
# 212/212 [==============================] - 0s 113us/sample - loss: 0.3745 - accuracy: 0.8538
# Epoch 47/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.3722 - accuracy: 0.8255
# Epoch 48/600
# 212/212 [==============================] - 0s 137us/sample - loss: 0.3478 - accuracy: 0.8443
# Epoch 49/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.3585 - accuracy: 0.8491
# Epoch 50/600
# 212/212 [==============================] - 0s 127us/sample - loss: 0.3406 - accuracy: 0.8491
# Epoch 51/600
# 212/212 [==============================] - 0s 141us/sample - loss: 0.4375 - accuracy: 0.8208
# Epoch 52/600
# 212/212 [==============================] - 0s 137us/sample - loss: 0.3725 - accuracy: 0.8538
# Epoch 53/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.4072 - accuracy: 0.8632
# Epoch 54/600
# 212/212 [==============================] - 0s 127us/sample - loss: 0.3519 - accuracy: 0.8915
# Epoch 55/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.3308 - accuracy: 0.8443
# Epoch 56/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.3366 - accuracy: 0.8632
# Epoch 57/600
# 212/212 [==============================] - 0s 146us/sample - loss: 0.3295 - accuracy: 0.8585
# Epoch 58/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.3695 - accuracy: 0.8349
# Epoch 59/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.3494 - accuracy: 0.8679
# Epoch 60/600
# 212/212 [==============================] - 0s 118us/sample - loss: 0.3389 - accuracy: 0.8396
# Epoch 61/600
# 212/212 [==============================] - 0s 113us/sample - loss: 0.3192 - accuracy: 0.8679
# Epoch 62/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.3509 - accuracy: 0.8774
# Epoch 63/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.3264 - accuracy: 0.8915
# Epoch 64/600
# 212/212 [==============================] - 0s 108us/sample - loss: 0.3457 - accuracy: 0.8632
# Epoch 65/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.3467 - accuracy: 0.8585
# Epoch 66/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.3596 - accuracy: 0.8632
# Epoch 67/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.3593 - accuracy: 0.8491
# Epoch 68/600
# 212/212 [==============================] - 0s 127us/sample - loss: 0.3394 - accuracy: 0.8632
# Epoch 69/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.3352 - accuracy: 0.8679
# Epoch 70/600
# 212/212 [==============================] - 0s 127us/sample - loss: 0.3516 - accuracy: 0.8585
# Epoch 71/600
# 212/212 [==============================] - 0s 127us/sample - loss: 0.3150 - accuracy: 0.8632
# Epoch 72/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.2986 - accuracy: 0.8868
# Epoch 73/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.2919 - accuracy: 0.8632
# Epoch 74/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.2912 - accuracy: 0.8774
# Epoch 75/600
# 212/212 [==============================] - 0s 118us/sample - loss: 0.3670 - accuracy: 0.8868
# Epoch 76/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.3194 - accuracy: 0.8821
# Epoch 77/600
# 212/212 [==============================] - 0s 137us/sample - loss: 0.2950 - accuracy: 0.8679
# Epoch 78/600
# 212/212 [==============================] - 0s 146us/sample - loss: 0.2577 - accuracy: 0.9245
# Epoch 79/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.2861 - accuracy: 0.9198
# Epoch 80/600
# 212/212 [==============================] - 0s 151us/sample - loss: 0.2908 - accuracy: 0.8868
# Epoch 81/600
# 212/212 [==============================] - 0s 127us/sample - loss: 0.2766 - accuracy: 0.9104
# Epoch 82/600
# 212/212 [==============================] - 0s 146us/sample - loss: 0.3215 - accuracy: 0.8632
# Epoch 83/600
# 212/212 [==============================] - 0s 141us/sample - loss: 0.2981 - accuracy: 0.8868
# Epoch 84/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.3417 - accuracy: 0.8679
# Epoch 85/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.3189 - accuracy: 0.8774
# Epoch 86/600
# 212/212 [==============================] - 0s 127us/sample - loss: 0.3273 - accuracy: 0.8679
# Epoch 87/600
# 212/212 [==============================] - 0s 137us/sample - loss: 0.3041 - accuracy: 0.9009
# Epoch 88/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.3274 - accuracy: 0.8774
# Epoch 89/600
# 212/212 [==============================] - 0s 141us/sample - loss: 0.3177 - accuracy: 0.8774
# Epoch 90/600
# 212/212 [==============================] - 0s 141us/sample - loss: 0.3078 - accuracy: 0.8679
# Epoch 91/600
# 212/212 [==============================] - 0s 141us/sample - loss: 0.3212 - accuracy: 0.8868
# Epoch 92/600
# 212/212 [==============================] - 0s 151us/sample - loss: 0.3384 - accuracy: 0.8915
# Epoch 93/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.3212 - accuracy: 0.8632
# Epoch 94/600
# 212/212 [==============================] - 0s 141us/sample - loss: 0.3093 - accuracy: 0.8726
# Epoch 95/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.2965 - accuracy: 0.8821
# Epoch 96/600
# 212/212 [==============================] - 0s 137us/sample - loss: 0.2631 - accuracy: 0.8774
# Epoch 97/600
# 212/212 [==============================] - 0s 137us/sample - loss: 0.3013 - accuracy: 0.9057
# Epoch 98/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.2586 - accuracy: 0.9198
# Epoch 99/600
# 212/212 [==============================] - 0s 127us/sample - loss: 0.2769 - accuracy: 0.9245
# Epoch 100/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.2741 - accuracy: 0.8774
# Epoch 101/600
# 212/212 [==============================] - 0s 146us/sample - loss: 0.2735 - accuracy: 0.9057
# Epoch 102/600
# 212/212 [==============================] - 0s 132us/sample - loss: 0.3253 - accuracy: 0.8821
# Epoch 103/600
# 212/212 [==============================] - 0s 123us/sample - loss: 0.2747 - accuracy: 0.9057

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                multiple                  420
# _________________________________________________________________
# dropout (Dropout)            multiple                  0
# _________________________________________________________________
# dense_1 (Dense)              multiple                  315
# _________________________________________________________________
# dropout_1 (Dropout)          multiple                  0
# _________________________________________________________________
# dense_2 (Dense)              multiple                  16
# =================================================================
# Total params: 751
# Trainable params: 751
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Loss x Accuracy
# _____

# %%
pd.DataFrame(history.history).plot();

plt.tight_layout();

# %% [markdown]
# #### Predictions
# ____

# %%
predictions = model.predict_classes(X_test)

# %% [markdown]
# #### Evaluation
# ___

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85        51
#            1       0.85      0.72      0.78        40
#
#     accuracy                           0.82        91
#    macro avg       0.83      0.81      0.82        91
# weighted avg       0.83      0.82      0.82        91

# %%
fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, predictions),
                                show_absolute=True,
                                show_normed=True,
                                colorbar=True, class_names=['Healthy','Sick'],)
plt.show()

# %% [markdown]
# #### Method 2
# ##### K-Fold
# ___

# %% [markdown]
# #### Get Y and Y data
# ________

# %%
X = master.drop('label', axis=1).values    
y = master['label'].values

# %% [markdown]
# #### Scale & Normalize Training Features
# ____

# %%
scaler = MinMaxScaler()
scaler.fit(X)

X = scaler.transform(X)

# %% [markdown]
# #### K Fold Cross Validation
# ____

# %%
def get_model():
    model = Sequential()
    
    model.add(Dense(units=20, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(units=15, activation='relu'))
    model.add(Dropout(0.5))
    
    model.add(Dense(units=1, activation='sigmoid'))    

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    return model

# %%
early_stop = EarlyStopping(monitor='loss', mode='min', verbose=0, patience=25)

model = KerasClassifier(build_fn=get_model, epochs=600, batch_size=10, verbose=0)
kfold = StratifiedKFold(n_splits=10, shuffle=True)

results = cross_val_score(model, X, y, cv=kfold, fit_params={'callbacks' : [early_stop]})

# %%
results.mean()
# Out:
# 0.8613978445529937
