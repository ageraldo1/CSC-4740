# %% [markdown]
# #### Dependencies
# ____

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pydot

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics

from tensorflow.keras.utils  import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import load_model

# %matplotlib inline

sns.set_style("whitegrid")

# %% [markdown]
# #### Load Data
# _____

# %%
master = pd.read_csv('../resources/fake_reg.csv')

master.head(5)
# Out:
#         price     feature1     feature2
# 0  461.527929   999.787558   999.766096
# 1  548.130011   998.861615  1001.042403
# 2  410.297162  1000.070267   998.844015
# 3  540.382220   999.952251  1000.440940
# 4  546.024553  1000.446011  1000.338531

# %%
master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
# price       1000 non-null float64
# feature1    1000 non-null float64
# feature2    1000 non-null float64
# dtypes: float64(3)
# memory usage: 23.6 KB

# %% [markdown]
# #### Data Analysis
# _____

# %%
sns.pairplot(data=master);

# %% [markdown]
# #### Split Train and Test Data
# ________

# %%
X = master[['feature1', 'feature2']].values    # NumPy array (TF requirement)
y = master['price'].values                     # NumPy array (TF requirement)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# #### Scale & Normalize Training Features
# ____

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
print(f'X_train shape : {X_train.shape} - Y_train shape : {y_train.shape}')
print(f'X_test shape : {X_test.shape} - Y_test shape : {y_test.shape}')
# Out:
# X_train shape : (700, 2) - Y_train shape : (700,)
# X_test shape : (300, 2) - Y_test shape : (300,)

# %% [markdown]
# #### Create Model
# ____

# %%
model = Sequential()

#input layer
#model.add(Dense(units=4, input_shape=(2,), activation='relu'))   

model.add(Dense(units=4, activation='relu'))
model.add(Dense(units=4, activation='relu'))
model.add(Dense(units=4, activation='relu'))

#output layer
model.add(Dense(units=1))    

model.compile(optimizer='rmsprop', loss='mse')   # regression
history = model.fit(x=X_train, y=y_train, epochs=250, verbose=0)

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_24 (Dense)             multiple                  12
# _________________________________________________________________
# dense_25 (Dense)             multiple                  20
# _________________________________________________________________
# dense_26 (Dense)             multiple                  20
# _________________________________________________________________
# dense_27 (Dense)             multiple                  5
# ...
# Total params: 57
# Trainable params: 57
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True,expand_nested=False)

# %%
#https://keras.io/visualization/
# Plot training & validation loss values
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
#plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# #### Predictions
# _____

# %%
predictions = model.predict(X_test)

# %% [markdown]
# #### Evaluation
# ____

# %%
pd.DataFrame(model.history.history).plot()

# %%
model.evaluate(X_test, y_test, verbose=0)
# Out:
# 26.7951575978597

# %%
print(f'Absolute Mean Error : {metrics.mean_absolute_error(y_test, predictions)}')
print(f'Mean Squared Error : {metrics.mean_squared_error(y_test, predictions)}')
print(f'Root Mean Squared Error : {np.sqrt(metrics.mean_squared_error(y_test, predictions))}')
# Out:
# Absolute Mean Error : 4.1605510176071
# Mean Squared Error : 26.79516245519088
# Root Mean Squared Error : 5.176404394479905

# %%
master.describe()
# Out:
#              price     feature1     feature2
# count  1000.000000  1000.000000  1000.000000
# mean    498.673029  1000.014171   999.979847
# std      93.785431     0.974018     0.948330
# min     223.346793   997.058347   996.995651
# 25%     433.025732   999.332068   999.316106
# 50%     502.382117  1000.009915  1000.002243
# 75%     564.921588  1000.637580  1000.645380
# max     774.407854  1003.207934  1002.666308

# %%
metrics.explained_variance_score(y_test, predictions)
# Out:
# 0.9971827293970609

# %%
pred_df = pd.DataFrame(y_test, columns=['Test True Y'])
pred_df = pd.concat([pred_df, pd.Series(predictions.reshape(300,))], axis=1)
pred_df.columns = ['Test True Y', 'Model Predictions']

pred_df
# Out:
#      Test True Y  Model Predictions
# 0     337.951295         341.715057
# 1     455.035335         450.084869
# 2     567.194706         557.098816
# 3     308.223431         311.898407
# 4     526.101920         524.178284
# ..           ...                ...
# 295   487.469524         495.808929
# 296   461.179445         464.575500
# 297   391.124667         396.401642
# 298   411.356362         412.176147
# 299   497.491482         490.154480
#
# [300 rows x 2 columns]

# %%
sns.scatterplot(x='Test True Y', y='Model Predictions', data=pred_df);

# %% [markdown]
# #### Predictions new Data
# _____

# %%
new_gem = [[998, 1000]]
new_gem = scaler.transform(new_gem)

# %%
model.predict(new_gem)
# Out:
# array([[420.37363]], dtype=float32)

# %% [markdown]
# #### Save Model
# _____

# %%
#model.save('my_gem_model.h5')
#later_model = load_model('my_gem_model.h5')
#later_model.predict(..)
