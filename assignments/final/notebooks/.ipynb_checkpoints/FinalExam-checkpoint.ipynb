# %% [markdown]
# #### Dependencies
# _____

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pydot

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

from mlxtend.plotting import plot_confusion_matrix

from IPython.display import Image
from sklearn.externals.six import StringIO
from sklearn.tree import export_graphviz

# %matplotlib inline

sns.set_style("whitegrid")

# %% [markdown]
# #### Load Data
# _____

# %% [markdown]
# ##### **Features Description**
#  + **Continuous**
#      + age
#      + trestbps (resting blood pressure (in mm Hg on admission to the hospital))
#      + chol (serum cholestoral in mg/dl)
#      + thalach (pncaden (sum of 5, 6, and 7))
#
#
#  + **Categorical**
#     + sex
#         + 1 = male
#         + 0 = female
#      + cp (chest pain type)
#          + 1 = typical angina
#          + 2 = atypical angina
#          + 3 = non-anginal pain
#          + 4 = asymptomatic
#
#      + fbs (fasting blood sugar > 120 mg/dl)
#          + 1 = true
#          + 0 = false
#
#      + restecg (resting electrocardiographic results)
#          + 0 = normal
#          + 1 = having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
#          + 2 = showing probable or definite left ventricular hypertrophy by Estes' criteria
#
#      + exang (exercise induced angina)
#          + 1 = yes
#          + 0 = no
#      + oldpeak (ST depression induced by exercise relative to rest)
#      + slope (the slope of the peak exercise ST segment)
#          + 1 = upsloping
#          + 2 = flat
#          + 3 = downsloping
#      + ca (number of major vessels (0-3) colored by flourosopy)
#         + 0 = zero fluroscopy colored Major Vessels
#         + 1 = one fluroscopy colored Major Vessels
#         + 2 = two fluroscopy colored Major Vessels
#         + 3 = three fluroscopy colored Major Vessels
#
#      + thal
#          + 3 = normal
#          + 6 = fixed defect
#          + 7 = reversable defect
#
# ##### **Label**
# + 0 = Healthy
# + 1-4 = Sick

# %%
columns = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'label']
master = pd.read_csv('../resources/processed.cleveland.data', names=columns)

master.head(5)
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  label
# 0    3.0  0.0  6.0      0
# 1    2.0  3.0  3.0      2
# 2    2.0  2.0  7.0      1
# 3    3.0  0.0  3.0      0
# 4    1.0  0.0  3.0      0

# %% [markdown]
# #### Data Cleanup
# _____

# %% [markdown]
# ##### Replacing the missing values by most frequent value

# %%
cond = master['ca'] == '?'
for row in master[cond]['ca'].index:
    master.iloc[row, 11] = master['ca'].mode().values
    
cond = master['thal'] == '?'
for row in master[cond]['thal'].index:
    master.iloc[row, 12] = master['thal'].mode().values
    
master['ca'] = master['ca'].astype('float64')
master['thal'] = master['thal'].astype('float64')

master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    float64
#  1   sex       303 non-null    float64
#  2   cp        303 non-null    float64
#  3   trestbps  303 non-null    float64
#  4   chol      303 non-null    float64
#  5   fbs       303 non-null    float64
#  6   restecg   303 non-null    float64
#  7   thalach   303 non-null    float64
#  8   exang     303 non-null    float64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    float64
#  11  ca        303 non-null    float64
#  12  thal      303 non-null    float64
#  13  label     303 non-null    int64
# dtypes: float64(13), int64(1)
# memory usage: 33.3 KB

# %% [markdown]
# ##### Converting label to binary (0 =  Healthy, 1 = Sick)

# %%
master['label'] = master['label'].apply(lambda x: 0 if x == 0 else 1)

# %% [markdown]
# ##### Checking for any missing data
# ___

# %%
master.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# label       0
# dtype: int64

# %% [markdown]
# #### Data Analysis
# _____

# %% [markdown]
# ##### Categorical Labels
# ___

# %%
def label_cp(x):
    if (x == 1):
        return 'typical-angina'
    
    elif (x == 2):
        return 'atypical-angina'
    
    elif (x == 3):
        return 'non-anginal-pain'
    
    else:
        return 'asymptomatic'
    
def label_restecg(x):
    if (x == 0):
        return 'normal'
    elif (x == 1):
        return 'wave-abnormality'
    else:
        return 'ventricular-hypertrophy'
    
def label_slope(x):
    if (x == 1):
        return 'upsloping'
    
    elif (x == 2):
        return 'flat'
    
    else:
        return 'downsloping'
    
def label_thal(x):
    if (x == 3):
        return 'normal'
    
    elif (x == 6):
        return 'fixed-defect'
    
    else:
        return 'reversable-defect'
    
def label_ca(x):
    if (x == 0):
        return 'zero'
    
    elif(x == 1):
        return 'one'
    
    elif(x == 2):
        return 'two'
    
    else:
        return 'three'        
        
master['sex'] = master['sex'].apply(lambda x: 'Male' if x == 1 else 'Female')
master['cp'] = master['cp'].apply(label_cp)
master['fbs'] = master['fbs'].apply(lambda x: 'False' if x == 0 else 'True')
master['restecg'] = master['restecg'].apply(label_restecg)
master['exang'] = master['exang'].apply(lambda x: 'No' if x == 0 else 'Yes')
master['slope'] = master['slope'].apply(label_slope)
master['thal'] = master['thal'].apply(label_thal)
master['ca'] = master['ca'].apply(label_ca)

data_d = master.copy(deep=True)
data_d['label'] = data_d['label'].apply(lambda x: 'Healthy' if x == 0 else 'Sick')

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='label', data=data_d);
plt.tight_layout()

# %% [markdown]
# ##### Distribution of data accross features
# ___

# %%
fig, axes =  plt.subplots(nrows=1, ncols=2, figsize=(14,4), dpi=100)

axes[0].set_title('Gender Distribution')
sns.countplot(x=data_d['sex'],ax=axes[0])

axes[1].set_title('Chest Pain Type')
sns.countplot(x=data_d['cp'], ax=axes[1])

fig, ax =  plt.subplots(nrows=1, ncols=2, figsize=(14,4), dpi=100)

ax[0].set_title('Age Distribution')
sns.distplot(data_d['age'], kde=False,color='blue', ax=ax[0])

ax[1].set_title('Blood Pressure Distribution')
sns.distplot(data_d['trestbps'], kde=False,color='red', ax=ax[1])


plt.tight_layout()

# %% [markdown]
# ##### Distribution of data accross features versus label
# ____

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20,10))

sns.boxplot(x='label', y='age', data=data_d, ax=axes[0][0], hue='sex')
axes[0][0].set_title('Distribution of Heart Disease accross Gender')

axes[0][1].set_title('Distribution of Heart Disease accross Blood Pressure')
sns.boxplot(x='label', y='trestbps', data=data_d, hue='sex', ax=axes[0][1])

axes[1][0].set_title('Distribution of Heart Disease accross Chest Pain')
sns.boxplot(x='label', y='age', data=data_d, hue='cp', ax=axes[1][0])

axes[1][1].set_title('Distribution of Heart Disease accross Induced Angina')
sns.boxplot(x='label', y='age', data=data_d, hue='exang', ax=axes[1][1])


plt.tight_layout()

# %% [markdown]
# ##### Correlation between age and blood pressure and between age and cholestoral
# ___

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14,6))

axes[0].set_title('Correlation between age and blood pressure')
sns.regplot(x='age', y='trestbps',data=master, ax=axes[0], color='red')

axes[1].set_title('Correlation between age and cholestoral')
sns.regplot(x='age', y='chol',data=master, ax=axes[1], color='green')

plt.tight_layout()

# %% [markdown]
# #### Encode Categorial Data
# _____

# %%
columns = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal']
dummies = pd.get_dummies(master[columns], drop_first=True)

master = master.drop(columns, axis=1)
master = pd.concat([master, dummies], axis=1)

master.columns
# Out:
# Index(['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'label', 'sex_Male',
#        'cp_atypical-angina', 'cp_non-anginal-pain', 'cp_typical-angina',
#        'fbs_True', 'restecg_ventricular-hypertrophy',
#        'restecg_wave-abnormality', 'exang_Yes', 'slope_flat',
#        'slope_upsloping', 'ca_three', 'ca_two', 'ca_zero', 'thal_normal',
#        'thal_reversable-defect'],
#       dtype='object')

# %% [markdown]
# #### Split Train and Test Data
# ________

# %%
X = master.drop('label', axis=1)
y = master['label']                 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

print(f'X_train shape : {X_train.shape} - Y_train shape : {y_train.shape}')
print(f'X_test shape : {X_test.shape} - Y_test shape : {y_test.shape}')
# Out:
# X_train shape : (212, 20) - Y_train shape : (212,)
# X_test shape : (91, 20) - Y_test shape : (91,)

# %% [markdown]
# #### Scale & Normalize Training Features
# ____

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### Classification Models Evaluation
# ____

# %% [markdown]
# ##### 1. LogisticRegression
# ____

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# ##### Predictions
# _____

# %%
predictions = model.predict(X_test)

# %% [markdown]
# ##### Model Evaluation
# _____

# %% [markdown]
# ##### Classification Report

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.87        51
#            1       0.84      0.80      0.82        40
#
#     accuracy                           0.85        91
#    macro avg       0.85      0.84      0.84        91
# weighted avg       0.85      0.85      0.85        91

# %% [markdown]
# ##### Confusion Matrix

# %%
fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, predictions),
                                show_absolute=True,
                                show_normed=True,
                                colorbar=True, class_names=['Healthy','Sick'],)
plt.show()

# %% [markdown]
# ##### 2. K Nearest Neighbors
# ____

# %%
model = KNeighborsClassifier(n_neighbors=1)
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %% [markdown]
# ##### Predictions
# _____

# %%
predictions = model.predict(X_test)

# %% [markdown]
# ##### Model Evaluation
# _____

# %% [markdown]
# ##### Classification Report

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.75      0.74        51
#            1       0.67      0.65      0.66        40
#
#     accuracy                           0.70        91
#    macro avg       0.70      0.70      0.70        91
# weighted avg       0.70      0.70      0.70        91

# %% [markdown]
# ##### Elbow Method to determinate the best k value

# %%
error_rate = []
lowest_error = 100
best_k = 0

for i in range(1, 100):
    model = KNeighborsClassifier(n_neighbors=i)
    model.fit(X_train, y_train)    
    predictions = model.predict(X_test)
    
    avg_error = np.mean(predictions != y_test)
    
    if (avg_error < lowest_error):
        lowest_error = avg_error
        best_k = i
    
    error_rate.append(avg_error)

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,100), error_rate, color='blue', linestyle='dashed', marker='o', markerfacecolor='red', markersize=10)
plt.title('Error Rate versus K Value')
plt.xlabel('K')
plt.ylabel('Error')

plt.tight_layout()

# %% [markdown]
# ##### Best k value : 49

# %%
model = KNeighborsClassifier(n_neighbors=best_k)
model.fit(X_train, y_train)
predictions = model.predict(X_test)

# %% [markdown]
# ##### Classification Report

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.87        51
#            1       0.84      0.80      0.82        40
#
#     accuracy                           0.85        91
#    macro avg       0.85      0.84      0.84        91
# weighted avg       0.85      0.85      0.85        91

# %% [markdown]
# ##### Confusion Matrix

# %%
fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, predictions),
                                show_absolute=True,
                                show_normed=True,
                                colorbar=True, class_names=['Healthy','Sick'],)
plt.show()

# %% [markdown]
# ##### 3. Decision Tree
# ____

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# ##### Predictions
# _____

# %%
predictions = model.predict(X_test)

# %% [markdown]
# ##### Model Evaluation
# _____

# %% [markdown]
# ##### Classification Report

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.75      0.74        51
#            1       0.67      0.65      0.66        40
#
#     accuracy                           0.70        91
#    macro avg       0.70      0.70      0.70        91
# weighted avg       0.70      0.70      0.70        91

# %% [markdown]
# ##### Confusion Matrix

# %%
fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, predictions),
                                show_absolute=True,
                                show_normed=True,
                                colorbar=True, class_names=['Healthy','Sick'],)
plt.show()

# %% [markdown]
# ##### Decision Tree Visualization

# %%
dot_data = StringIO()
export_graphviz(model, out_file=dot_data, feature_names=list(master.columns[1:]), filled=True)
graph = pydot.graph_from_dot_data(dot_data.getvalue())
Image(graph[0].create_png())

# %%
graph[0].write_png("../output/decisiontree.png")

# %% [markdown]
# ##### 4. Random Forest
# ____

# %%
model = RandomForestClassifier(n_estimators=300)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=300,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# ##### Predictions
# _____

# %%
predictions = model.predict(X_test)

# %% [markdown]
# ##### Model Evaluation
# _____

# %% [markdown]
# ##### Classification Report

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.80      0.79        51
#            1       0.74      0.70      0.72        40
#
#     accuracy                           0.76        91
#    macro avg       0.76      0.75      0.75        91
# weighted avg       0.76      0.76      0.76        91

# %% [markdown]
# ##### Confusion Matrix

# %%
fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, predictions),
                                show_absolute=True,
                                show_normed=True,
                                colorbar=True, class_names=['Healthy','Sick'],)
plt.show()

# %% [markdown]
# ##### 5. Support Vector Machine
# ____

# %%
model = SVC()
model.fit(X_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# ##### Predictions
# _____

# %%
predictions = model.predict(X_test)

# %% [markdown]
# ##### Model Evaluation
# _____

# %% [markdown]
# ##### Classification Report

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.84        51
#            1       0.81      0.75      0.78        40
#
#     accuracy                           0.81        91
#    macro avg       0.81      0.81      0.81        91
# weighted avg       0.81      0.81      0.81        91

# %% [markdown]
# ##### Confusion Matrix

# %%
fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, predictions),
                                show_absolute=True,
                                show_normed=True,
                                colorbar=True, class_names=['Healthy','Sick'],)
plt.show()

# %% [markdown]
# ##### GridSearch

# %%
params = {
    'C' : [0.1, 1,10,100,1000],
    'gamma' : [1, 0.1, 0.01, 0.001, 0.0001, 0.00001]    
}

grid = GridSearchCV(SVC(), param_grid=params, verbose=3)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ...................... C=0.1, gamma=1, score=0.558, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ...................... C=0.1, gamma=1, score=0.605, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ...................... C=0.1, gamma=1, score=0.548, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ...................... C=0.1, gamma=1, score=0.595, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ...................... C=0.1, gamma=1, score=0.643, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] .................... C=0.1, gamma=0.1, score=0.907, total=   0.0s
# ...

# %%
grid.best_estimator_
# Out:
# SVC(C=10, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# ##### Prediction using optimized parameters

# %%
predictions = grid.predict(X_test)

# %% [markdown]
# ##### Classification Report

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84        51
#            1       0.83      0.72      0.77        40
#
#     accuracy                           0.81        91
#    macro avg       0.82      0.80      0.81        91
# weighted avg       0.81      0.81      0.81        91

# %% [markdown]
# ##### Confusion Matrix

# %%
fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, predictions),
                                show_absolute=True,
                                show_normed=True,
                                colorbar=True, class_names=['Healthy','Sick'],)
plt.show()
